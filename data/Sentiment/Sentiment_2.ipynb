# %%
import psycopg2
from sshtunnel import SSHTunnelForwarder
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from dotenv import load_dotenv
import os

# %%
# Load environment variables from .env file
load_dotenv()

# Get info from .env
SSH_HOST = os.getenv('SSH_HOST')
SSH_PORT = int(os.getenv('SSH_PORT'))
SSH_USER = os.getenv('SSH_USER')
SSH_PASSWORD = os.getenv('SSH_PASSWORD')

POSTGRES_HOST = os.getenv('POSTGRES_HOST')
POSTGRES_USER = os.getenv('POSTGRES_USER')
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')
POSTGRES_DB = os.getenv('POSTGRES_DB')
POSTGRES_PORT = int(os.getenv('POSTGRES_PORT'))

# %%
# SSH tunnel
tunnel = SSHTunnelForwarder(
    (SSH_HOST, SSH_PORT),
    ssh_username=SSH_USER,
    ssh_password=SSH_PASSWORD,
    remote_bind_address=(POSTGRES_HOST, POSTGRES_PORT),
    local_bind_address=('127.0.0.1', 5433)
)
tunnel.start()

connection = psycopg2.connect(
    database=POSTGRES_DB,
    user=POSTGRES_USER,
    password=POSTGRES_PASSWORD,
    host='127.0.0.1',
    port=tunnel.local_bind_port
)
cursor = connection.cursor()

# %%
# Fetch comments from db
cursor.execute("SELECT id, comment FROM comments_fs WHERE comment IS NOT NULL")
comments = cursor.fetchall()

# %%
import pandas as pd
import nltk

# VADER sentiment analyser
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

# %%
# Function to classify sentiment
def classify_sentiment(score):
    if score['compound'] >= 0.05:
        return 1
    elif score['compound'] <= -0.05:
        return -1
    else:
        return 0

# %%
sql = """
ALTER TABLE comments_fs ADD COLUMN sentiment INTEGER;
"""

try:
    cursor.execute(sql)
    connection.commit()
except Exception as e:
    print(e)

# %%
# Update sentiment scores in the database
for comment_id, comment in comments:
    sentiment_score = sia.polarity_scores(comment)
    sentiment = classify_sentiment(sentiment_score)
    cursor.execute("UPDATE comments_fs SET sentiment = %s WHERE id = %s", (sentiment, comment_id))

# %%
# Commit changes and close connection
connection.commit()
cursor.close()
connection.close()
tunnel.close()

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df = pd.read_csv('comments_fs.csv')

df.shape
# Out:
# (18161, 7)

# %%
# VADER sentiment analyser
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/muireannoconnor/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Classify sentiment
def classify_sentiment(score):
    if score['compound'] >= 0.05:
        return 1
    elif score['compound'] <= -0.05:
        return -1
    else:
        return 0

# %%
# Sentiment analysis for each comment
df['sentiment'] = df['comment'].apply(lambda comment: classify_sentiment(sia.polarity_scores(comment)))

# %%
df.head(20)
# Out:
#     id                             name  \
# 0    1         Equinox Brookfield Place
# 1    2         Equinox Brookfield Place
# 2    3         Equinox Brookfield Place
# 3    4         Equinox Brookfield Place
# 4    5         Equinox Brookfield Place
# 5    6                    Asphalt Green
# 6    7                    Asphalt Green
# 7    8                    Asphalt Green
# 8    9                    Asphalt Green
# 9   10                    Asphalt Green
# 10  11     Battery Park City Ballfields
# 11  12     Battery Park City Ballfields
# 12  13     Battery Park City Ballfields
# 13  14     Battery Park City Ballfields
# 14  15     Battery Park City Ballfields
# 15  16  American Express Fitness Center
# 16  17  American Express Fitness Center
# 17  18  American Express Fitness Center
# 18  19  American Express Fitness Center
# 19  20  American Express Fitness Center
#
#                                             address  \
# 0   225 Liberty St (at West St), New York, NY 10281
